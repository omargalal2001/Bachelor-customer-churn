# %% [markdown]
# <a href="https://colab.research.google.com/github/omargalal2001/Bachelor-customer-churn/blob/main/bachelor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Description

# %% [markdown]
# *   **State** : the code of the state the customer is from, Account length,
#
# *   **Area code**: the area the customer is residing in
#
# *   international plan
#
# *   Voice mail plan
#
# *   Number of v-mail messages
#
# * international plan
#
# *   Voice mail plan
#
# *   Number of v-mail messages **bold text**
#
# * **Total day minutes**: representing the sum of minutes they’ve spent on a call during the day
#
# *  **Total day calls** : representing the sum of calls done during the day
#
# *   **Total eve minutes** : the sum of minutes they’ve spent on a call during the evening
#
# *   ** Total eve calls** : sum of calls done during the evening
#
# *  **  Total night minutes** : sum of minutes they’ve spent on a call during the night
#
# *    **Total night calls** : sum of calls they’ve done during the night
#
# *    Total intl minutes :sum of international minutes they’ve spent during line’s lifetime
#
# *    Total intl calls :sum of international calls the user of the phone did
#
# *    total intl charge : representing how much the customer was charged for the international phone call
#
# *    customer service calls : which is the number of times the customer has called customer service since joining the company
#
# *    churn : which represents if the customer left the service provider or not.---
# ---
# ---
#
#    There are no missing values and all the value types are consistent with their respective attribute type. In the table below we showcase the various attributes and their corresponding attribute types. All of these attributes can be ascribed as customer data as they all are information about the customer.

# %% [markdown]
# # **Importing & reading data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline
plt.style.use("seaborn")


df = pd.read_csv("churn-bigml-80.csv")
#df = pd.read_csv('https://github.com/omargalal2001/Bachelor-customer-churn/blob/main/churn-bigml-80.csv')

df.head()
# Out:
# <ipython-input-2-32f83bc00fed>:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# ...

# %% [markdown]
# # **Data Inspection**

# %%
df
df.info()
df.describe(include='all')
df.isnull().sum() // check nulls
print(df['variable name'].unique())


Data cleaning 

df['MonthlyCharges'] = df['MonthlyCharges'].str.replace('$', '')//  to replace

df['MonthlyCharges'] = df['MonthlyCharges'].str.replace('$', '').astype(float)//  to replace and set type

dff['StreamingMovies'] = dff['StreamingMovies'].astype('category').cat.codes // to set type

df = df.fillna(df['TotalCharges'].mean()) // to fill nulls with mean. // df.isnull().sum() to check kolo l mafrod yekon ziro 

// finaly to drop.  df = df.drop(['customerID'],axis = 1)
# Out:
#   File "<ipython-input-52-0a0c6dfed029>", line 4
#     df.isnull().sum() // check nulls
#                                ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
df.describe(include='all')
# Out:
#        State  Account length    Area code International plan Voice mail plan  \
# count   2666     2666.000000  2666.000000               2666            2666
# unique    51             NaN          NaN                  2               2
# top       WV             NaN          NaN                 No              No
# freq      88             NaN          NaN               2396            1933
# mean     NaN      100.620405   437.438860                NaN             NaN
# std      NaN       39.563974    42.521018                NaN             NaN
# min      NaN        1.000000   408.000000                NaN             NaN
# 25%      NaN       73.000000   408.000000                NaN             NaN
# 50%      NaN      100.000000   415.000000                NaN             NaN
# 75%      NaN      127.000000   510.000000                NaN             NaN
# max      NaN      243.000000   510.000000                NaN             NaN
#
# ...

# %% [markdown]
# Checking nulls

# %%
df.isnull().sum()
#  no nulls

# %%
df['Total day minutes'] = df['Total day minutes'].str.replace('...', 'kk')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-9633c4a36dec> in <cell line: 1>()
# ----> 1 df['Total day minutes'] = df['Total day minutes'].str.replace('...', 'kk')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
# ...

# %%
# //Checking the unique values for each column

for column in df.columns:
    print(f"{column} : {df[column].unique()}")
    print("====================================")
# Out:
# State : ['KS' 'OH' 'NJ' 'OK' 'AL' 'MA' 'MO' 'WV' 'RI' 'IA' 'MT' 'ID' 'VT' 'VA'
#  'TX' 'FL' 'CO' 'AZ' 'NE' 'WY' 'IL' 'NH' 'LA' 'GA' 'AK' 'MD' 'AR' 'WI'
#  'OR' 'DE' 'IN' 'UT' 'CA' 'SD' 'NC' 'WA' 'MN' 'NM' 'NV' 'DC' 'NY' 'KY'
#  'ME' 'MS' 'MI' 'SC' 'TN' 'PA' 'HI' 'ND' 'CT']
# ...
# Account length : [128 107 137  84  75 118 121 147 141  74 168  95  62  85  93  76  73  77
#  130 132 174  57  54  20 142 172  12  72  78 136 149  98 135  34 160  64
#   59  97  52  60  96  87  81 125 116  38  40  43 113 126 150 138 162  90
#   50  82 144  70  55 106  94 111  80 104  99 120 122 157 103  36 112  46
#   41 193  61  92 131 163  91 127 110 117 140  83 145  56 151 139 115 146
#  185 148  68 179  67  19 170 164  51  63  53 105  66  86  35  88 123 100
#  108  22  33 114  24 119 101  49  48  71 167 166 158 196 209  16  39 173
#  129 143  89  44  79  31  37 159 194 154  45  32  21 133  25 224  58 155
#   11 109 165  18 161 124  30 176  47 190 152  65 186 171 102  28 153 169
# ...

# %%
for column in df.columns:
    print(f"{column}: Number of unique values {df[column].nunique()}")
    print("==========================================================")
# Out:
# State: Number of unique values 51
# ...
# Account length: Number of unique values 205
# ...
# Area code: Number of unique values 3
# ...
# International plan: Number of unique values 2
# ...
# Voice mail plan: Number of unique values 2
# ...
# Number vmail messages: Number of unique values 42
# ...
# Total day minutes: Number of unique values 1489
# ...
# Total day calls: Number of unique values 115
# ...
# Total day charge: Number of unique values 1489
# ...
# Total eve minutes: Number of unique values 1442
# ...
# Total eve calls: Number of unique values 120
# ...
# Total eve charge: Number of unique values 1301
# ...
# Total night minutes: Number of unique values 1444
# ...
# Total night calls: Number of unique values 118
# ...
# Total night charge: Number of unique values 885
# ...
# Total intl minutes: Number of unique values 158
# ...
# Total intl calls: Number of unique values 21
# ...
# Total intl charge: Number of unique values 158
# ...
# Customer service calls: Number of unique values 10
# ...
# Churn: Number of unique values 2
# ...

# %%
print(df['state'].unique())

# %%
print(df['Account length'].unique())
# Out:
# [128 107 137  84  75 118 121 147 141  74 168  95  62  85  93  76  73  77
#  130 132 174  57  54  20 142 172  12  72  78 136 149  98 135  34 160  64
#   59  97  52  60  96  87  81 125 116  38  40  43 113 126 150 138 162  90
#   50  82 144  70  55 106  94 111  80 104  99 120 122 157 103  36 112  46
#   41 193  61  92 131 163  91 127 110 117 140  83 145  56 151 139 115 146
#  185 148  68 179  67  19 170 164  51  63  53 105  66  86  35  88 123 100
#  108  22  33 114  24 119 101  49  48  71 167 166 158 196 209  16  39 173
#  129 143  89  44  79  31  37 159 194 154  45  32  21 133  25 224  58 155
#   11 109 165  18 161 124  30 176  47 190 152  65 186 171 102  28 153 169
#   13  42 189  69  27 134 156 243  23 205 200   5   9 178 181 182 177 210
#  180   3  10   2  17 212   1  29 192 195   6 225 184 197  15 183 202   8
#  217   4 188   7 204 201 221]

# %%
print(df['Area code'].unique())
# Out:
# [415 408 510]

# %%
print(df['International plan'].unique())
# Out:
# ['No' 'Yes']

# %%
print(df['Number vmail messages'].unique())
# Out:
# [25 26  0 24 37 27 33 39 41 28 30 34 46 35 21 42 36 22 23 43 31 38 40 29
#  18 32 17 45 16 14 20 19 15 12 47  8 44  4 10 13 50  9]

# %%
print(df['Total day minutes'].unique())
# Out:
# [265.1 161.6 243.4 ... 106.6 231.1 180.8]

# %%
print(df['Total day charge'].unique())
# Out:
# [45.07 27.47 41.38 ... 18.12 39.29 30.74]

# %%
print(df['Total eve minutes'].unique())
# Out:
# [197.4 195.5 121.2 ... 153.4 288.8 265.9]

# %%
print(df['Total eve minutes']==189.7)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2661     True
# 2662    False
# 2663    False
# 2664    False
# 2665    False
# Name: Total eve minutes, Length: 2666, dtype: bool

# %%
print(df['Total eve calls'].unique())
# Out:
# [ 99 103 110  88 122 101 108  94 111 148  71  75  76  90  65  93 121  72
#  112 100  84  63 107 115 119 102 116  92  85  98 118  74  58  96  67  62
#   77 126 142  64  97 104  80  83 117  79  95 105  81 113 109  48  82  86
#   87 123 114 140 128 106  60 125  46 138 129  89 133 136  57 135 139  51
#   70  78 151  91 152 120  66 127 132 137  73 143  68  61  42  54 149 124
#  134 131  69 130  52  49  59 146 147  55  12  50 157  56  45 144  36 156
#   53 141  44 153 154 155 150  43   0 145 159 170]

# %%
print(df['Total eve charge'].unique())
# Out:
# [16.78 16.62 10.3  ... 13.04 24.55 22.6 ]

# %%
print(df['Account length'].unique())
# Out:
# [128 107 137  84  75 118 121 147 141  74 168  95  62  85  93  76  73  77
#  130 132 174  57  54  20 142 172  12  72  78 136 149  98 135  34 160  64
#   59  97  52  60  96  87  81 125 116  38  40  43 113 126 150 138 162  90
#   50  82 144  70  55 106  94 111  80 104  99 120 122 157 103  36 112  46
#   41 193  61  92 131 163  91 127 110 117 140  83 145  56 151 139 115 146
#  185 148  68 179  67  19 170 164  51  63  53 105  66  86  35  88 123 100
#  108  22  33 114  24 119 101  49  48  71 167 166 158 196 209  16  39 173
#  129 143  89  44  79  31  37 159 194 154  45  32  21 133  25 224  58 155
#   11 109 165  18 161 124  30 176  47 190 152  65 186 171 102  28 153 169
#   13  42 189  69  27 134 156 243  23 205 200   5   9 178 181 182 177 210
#  180   3  10   2  17 212   1  29 192 195   6 225 184 197  15 183 202   8
#  217   4 188   7 204 201 221]

# %% [markdown]
# # **Data Cleaning**

# %%
# df['MonthlyCharges'] = df['MonthlyCharges'].str.replace('$', '')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MonthlyCharges'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # Data visualizion

# %%
dff=df.copy()

# %% [markdown]
# # The  variables affecting customer churn are
# (+ve correlation 1:customer service calls, 2: total day minutes 3: total day charge
# --
# (-ve correlation 1:,2:tenure,3:online security )
# --

# %%
figure = plt.figure(figsize=(40,15))
sns.heatmap(dff.corr(), cmap='viridis', annot = True);
# Out:
# <ipython-input-66-cb4798ba7263>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dff.corr(), cmap='viridis', annot = True);

# %% [markdown]
# Percentages of churn rate based on states

# %%
xo =dff.groupby(['State','Churn']).size().unstack()
xo['Churn_ratio'] = xo[True] / (xo[False]+xo[True])
xo_sorted = xo.sort_values('Churn_ratio', ascending=False)
xo_sorted['Churn_ratio'] = xo_sorted['Churn_ratio'].apply(lambda x: '{:.2%}'.format(x))
xo_sorted
# Out:
# Churn  False  True Churn_ratio
# State
# TX        39    16      29.09%
# NJ        36    14      28.00%
# AR        36    11      23.40%
# MD        46    14      23.33%
# MS        37    11      22.92%
# SC        38    11      22.45%
# ME        38    11      22.45%
# MI        45    13      22.41%
# PA        28     8      22.22%
# NV        48    13      21.31%
# NH        34     9      20.93%
# WA        38    10      20.83%
# CA        19     5      20.83%
# KS        42    10      19.23%
# MT        43    10      18.87%
# CT        48    11      18.64%
# MN        57    13      18.57%
# NY        56    12      17.65%
# GA        41     8      16.33%
# NC        47     9      16.07%
# DE        43     8      15.69%
# MA        44     8      15.38%
# OH        56    10      15.15%
# KY        37     6      13.95%
# OK        45     7      13.46%
# UT        52     8      13.33%
# FL        47     7      12.96%
# SD        43     6      12.24%
# TN        36     5      12.20%
# ...

# %% [markdown]
# # Data Preprocessing

# %%
df_encoded = df.copy()

# %%
df.hist(figsize=(10,10));
